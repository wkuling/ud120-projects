# %%
#!/usr/bin/python

import os
import pickle
import re
import sys

sys.path.append( "../tools/" )
from parse_out_email_text import parseOutText

# %%
"""
    starter code to process the emails from Sara and Chris to extract
    the features and get the documents ready for classification

    the list of all the emails from Sara are in the from_sara list
    likewise for emails from Chris (from_chris)

    the actual documents are in the Enron email dataset, which
    you downloaded/unpacked in Part 0 of the first mini-project

    the data is stored in lists and packed away in pickle files at the end

"""


from_sara  = open("from_sara.txt", "r")
from_chris = open("from_chris.txt", "r")

from_data = []
word_data = []

### temp_counter is a way to speed up the development--there are
### thousands of emails from Sara and Chris, so running over all of them
### can take a long time
### temp_counter helps you only look at the first 200 emails in the list
temp_counter = 0


for name, from_person in [("sara", from_sara), ("chris", from_chris)]:
    for path in from_person:
        ### only look at first 200 emails when developing
        ### once everything is working, remove this line to run over full dataset
        #temp_counter += 1
        if temp_counter < 200:
            path = os.path.join('..', path[:-1])
            print temp_counter, path
            email = open(path, "r")

            ### use parseOutText to extract the text from the opened email
            
            words = parseOutText(email)
            if temp_counter==153:
                print words

            ### use str.replace() to remove any instances of the words
            ### ["sara", "shackleton", "chris", "germani"]
            
            for ii in ["sara", "shackleton", "chris", "germani"]:
                words = words.replace(ii, " ")

            ### append the text to word_data
            
            word_data.append(words)
            
            ### append a 0 to from_data if email is from Sara, and 1 if email is from Chris

            if name == "sara":
                from_data.append(0)
            elif name == "chris":
                from_data.append(1)

            email.close()

print "emails processed"
from_sara.close()
from_chris.close()

pickle.dump( word_data, open("your_word_data.pkl", "w") )
pickle.dump( from_data, open("your_email_authors.pkl", "w") )
# Out:
# 0 ..\maildir/bailey-s/deleted_items/101.
# 0 ..\maildir/bailey-s/deleted_items/106.
# 0 ..\maildir/bailey-s/deleted_items/132.
# 0 ..\maildir/bailey-s/deleted_items/185.
# 0 ..\maildir/bailey-s/deleted_items/186.
# 0 ..\maildir/bailey-s/deleted_items/187.
# 0 ..\maildir/bailey-s/deleted_items/193.
# 0 ..\maildir/bailey-s/deleted_items/195.
# 0 ..\maildir/bailey-s/deleted_items/214.
# 0 ..\maildir/bailey-s/deleted_items/215.
# 0 ..\maildir/bailey-s/deleted_items/233.
# 0 ..\maildir/bailey-s/deleted_items/242.
# 0 ..\maildir/bailey-s/deleted_items/243.
# 0 ..\maildir/bailey-s/deleted_items/244.
# 0 ..\maildir/bailey-s/deleted_items/246.
# 0 ..\maildir/bailey-s/deleted_items/247.
# 0 ..\maildir/bailey-s/deleted_items/254.
# 0 ..\maildir/bailey-s/deleted_items/259.
# 0 ..\maildir/bailey-s/deleted_items/260.
# 0 ..\maildir/bailey-s/deleted_items/261.
# 0 ..\maildir/bailey-s/deleted_items/263.
# 0 ..\maildir/bailey-s/deleted_items/278.
# 0 ..\maildir/bailey-s/deleted_items/290.
# ...

# %%
word_data[152]
# Out:
# u'tjonesnsf stephani and sam need nymex calendar'

# %%
len(word_data)
# Out:
# 17578

# %%
### in Part 4, do TfIdf vectorization here

# %%
# It seems the corpus has changed a little, as the right answer from Udacity is 38757 :(

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
sw = stopwords.words('english')

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer(stop_words="english")

# Note that stop_words here is different from nltk!

# %%
vector = vectorizer.fit_transform(word_data)

# %%
len(vectorizer.get_feature_names())
# Out:
# 38755

# %%
len(sw)
# Out:
# 127

# %%
vectorizer.get_feature_names()[34596]
# Out:
# u'stephenthatcherubswcom'
